# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-f763911ceade> in <module>()
#       1 import numpy as np
# ----> 2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#       4 get_ipython().magic(u'matplotlib inline')
#
# ImportError: No module named pandas

# %%
train = pd.read_csv("/Users/yijia/Desktop/Titanic/train.csv")
test = pd.read_csv('/Users/yijia/Desktop/Titanic/test.csv')

# %%
train.tail()
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train.describe()
# Out:
# /Users/yijia/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:4116: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000         NaN    0.000000
# 50%     446.000000    0.000000    3.000000         NaN    0.000000
# 75%     668.500000    1.000000    3.000000         NaN    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# ...

# %%
test.describe()
# Out:
# /Users/yijia/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:4116: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000         NaN    0.000000    0.000000         NaN
# 50%    1100.500000    3.000000         NaN    0.000000    0.000000         NaN
# 75%    1204.750000    3.000000         NaN    1.000000    0.000000         NaN
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
print (train.groupby(['Embarked']).count())
# Out:
#           PassengerId  Survived  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  \
# Embarked
# C                 168       168     168   168  168  168    168    168     168
# Q                  77        77      77    77   77   77     77     77      77
# S                 644       644     644   644  644  644    644    644     644
#
#           Fare  Cabin
# Embarked
# C          168     69
# Q           77      4
# S          644    129

# %%
train["Age"].fillna(train.Age.mean(), inplace= True)
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   13.002015    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
num_variable = list(train.dtypes[train.dtypes != "object"].index)
train[num_variable].head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1         0       3  22.0      1      0   7.2500
# 1            2         1       1  38.0      1      0  71.2833
# 2            3         1       3  26.0      0      0   7.9250
# 3            4         1       1  35.0      1      0  53.1000
# 4            5         0       3  35.0      0      0   8.0500

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
train[['Sex', 'Survived']].groupby(['Sex'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
train[['SibSp', 'Survived']].groupby(['SibSp'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %%
train[['Parch', 'Survived']].groupby(['Parch'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Parch  Survived
# 3      3  0.600000
# 1      1  0.550847
# 2      2  0.500000
# 0      0  0.343658
# 5      5  0.200000
# 4      4  0.000000
# 6      6  0.000000

# %%
# visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %%
g = sns.FacetGrid(train, col='Survived')
g.map(plt.hist, 'Age', bins=15)

# %%
g = sns.FacetGrid(train, col='Survived')
g.map(plt.hist, 'Age', bins=15)

# %%
combine = [train, test]
for dataset in combine:
    dataset['FamilySize'] = dataset['SibSp'] + dataset['Parch'] + 1

# %%
train[['FamilySize', 'Survived']].groupby(['FamilySize'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    FamilySize  Survived
# 3           4  0.724138
# 2           3  0.578431
# 1           2  0.552795
# 6           7  0.333333
# 0           1  0.303538
# 4           5  0.200000
# 5           6  0.136364
# 7           8  0.000000
# 8          11  0.000000

# %%
for dataset in combine:
    dataset['IsAlone'] = 0
    dataset.loc[dataset['FamilySize'] == 1, 'IsAlone'] = 1

train[['IsAlone', 'Survived']].groupby(['IsAlone'], as_index=False).mean()
# Out:
#    IsAlone  Survived
# 0        0  0.505650
# 1        1  0.303538

# %%
for dataset in combine:
    ticklen = []
    for name in dataset["Ticket"]:
        ticklen.append(len(name))
    dataset["ticket_len"] = ticklen
# Out:
# 891
# 418

# %%
train[['ticket_len', 'Survived']].groupby(['ticket_len'], as_index=False).mean()
# Out:
#     ticket_len  Survived
# 0            3  0.000000
# 1            4  0.366337
# 2            5  0.618321
# 3            6  0.319809
# 4            7  0.296296
# 5            8  0.539474
# 6            9  0.192308
# 7           10  0.341463
# 8           11  0.250000
# 9           12  0.400000
# 10          13  0.400000
# 11          15  0.333333
# 12          16  0.272727
# 13          17  0.428571
# 14          18  0.000000

# %%
train['ticketBend'] = pd.qcut(train['ticket_len'], 4)
train[['ticketBend', 'Survived']].groupby(['ticketBend'], as_index=False).mean().sort_values(by='ticketBend', ascending=True)
# Out:
#   ticketBend  Survived
# 0     [3, 5]  0.504274
# 1     (5, 6]  0.319809
# 2     (6, 7]  0.296296
# 3    (7, 18]  0.388626

# %%
for dataset in combine:
    tickdot = []
    for name in dataset["Ticket"]:
        tickdot.append(len(name.split("."))-1)
    dataset["ticket_dot"] = tickdot

# %%
train[['ticket_dot', 'Survived']].groupby(['ticket_dot'], as_index=False).mean()
# Out:
#    ticket_dot  Survived
# 0           0  0.396684
# 1           1  0.270270
# 2           2  0.314815
# 3           3  0.333333
# 4           4  0.000000

# %%
for dataset in combine:
    dataset["ticket_"] = dataset["ticket_len"] + dataset["ticket_dot"]

# %%
train[['ticket_', 'Survived']].groupby(['ticket_'], as_index=False).mean()
# Out:
#     ticket_  Survived
# 0         3  0.000000
# 1         4  0.366337
# 2         5  0.618321
# 3         6  0.319809
# 4         7  0.296296
# 5         8  0.597015
# 6         9  0.173913
# 7        10  0.250000
# 8        11  0.230769
# 9        12  0.333333
# 10       13  0.500000
# 11       14  0.000000
# 12       15  0.333333
# 13       16  0.000000
# 14       17  0.444444
# 15       18  0.384615
# 16       19  0.333333
# 17       20  0.000000

# %%
train['ticketBend'] = pd.qcut(train['ticket_'], 4)
train[['ticketBend', 'Survived']].groupby(['ticketBend'], as_index=False).mean().sort_values(by='ticketBend', ascending=True)
# Out:
#   ticketBend  Survived
# 0     [3, 5]  0.504274
# 1     (5, 6]  0.319809
# 2     (6, 7]  0.296296
# 3    (7, 20]  0.388626

# %%
for dataset in combine:
    tickspace = []
    for name in dataset["Ticket"]:
        tickspace.append(len(name.split(" "))-1)
    dataset["ticket_space"] = tickspace

# %%
train[['ticket_space', 'Survived']].groupby(['ticket_space'], as_index=False).mean()
# Out:
#    ticket_space  Survived
# 0             0  0.383459
# 1             1  0.380282
# 2             2  0.461538

# %%
for dataset in combine:
    dataset["ticket_"] = dataset["ticket_len"] + dataset["ticket_dot"] + dataset["ticket_space"]

# %%
train[['ticket_', 'Survived']].groupby(['ticket_'], as_index=False).mean()
# Out:
#     ticket_  Survived
# 0         3  0.000000
# 1         4  0.366337
# 2         5  0.618321
# 3         6  0.320482
# 4         7  0.250000
# 5         8  0.363636
# 6         9  0.597015
# 7        10  0.173913
# 8        11  0.250000
# 9        12  0.230769
# 10       13  0.333333
# 11       14  0.500000
# 12       15  0.000000
# 13       16  0.294118
# 14       17  0.200000
# 15       18  0.444444
# 16       19  0.000000
# 17       20  0.400000
# 18       21  0.000000

# %%
train['ticketBend'] = pd.qcut(train['ticket_'], 4)
train[['ticketBend', 'Survived']].groupby(['ticketBend'], as_index=False).mean().sort_values(by='ticketBend', ascending=True)
# Out:
#   ticketBend  Survived
# 0     [3, 5]  0.504274
# 1     (5, 6]  0.320482
# 2     (6, 7]  0.250000
# 3    (7, 21]  0.387387

# %%
for dataset in combine:
    dataset["fareper"] = dataset["Fare"]/dataset['FamilySize']

# %%
train[['fareper', 'Survived']].groupby(['fareper'], as_index=False).mean()
# Out:
#         fareper  Survived
# 0      0.000000  0.066667
# 1      1.132143  1.000000
# 2      2.409733  0.000000
# 3      2.583333  0.000000
# 4      2.618067  0.000000
# 5      2.641667  0.000000
# 6      2.875000  0.000000
# 7      2.887500  0.000000
# 8      3.125000  1.000000
# 9      3.247900  0.000000
# 10     3.487500  0.000000
# 11     3.522900  0.000000
# 12     3.527100  0.000000
# 13     3.625000  0.000000
# 14     3.711100  1.000000
# 15     3.875000  0.000000
# 16     3.887500  0.500000
# 17     3.927100  0.500000
# 18     3.962500  0.666667
# 19     4.012500  0.000000
# 20     4.202100  0.000000
# 21     4.215000  0.000000
# 22     4.258350  1.000000
# 23     4.333333  1.000000
# 24     4.467857  0.000000
# 25     4.483929  0.750000
# 26     4.600000  1.000000
# 27     4.650000  0.000000
# 28     4.675000  1.000000
# 29     4.702767  0.000000
# ..          ...       ...
# 259   66.825000  1.000000
# 260   69.300000  1.000000
# 261   70.500000  0.000000
# ...

# %%
train['fareperBend'] = pd.qcut(train['fareper'], 4)
train[['fareperBend', 'Survived']].groupby(['fareperBend'], as_index=False).mean().sort_values(by='fareperBend', ascending=True)
# Out:
#          fareperBend  Survived
# 0          [0, 7.25]  0.265487
# 1        (7.25, 8.3]  0.254545
# 2      (8.3, 23.667]  0.408072
# 3  (23.667, 512.329]  0.608108

# %%
for dataset in combine:
    dataset['Title'] = dataset.Name.str.extract(' ([A-Za-z]+)\.', expand=False)

pd.crosstab(train['Title'], train['Sex'])
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
for dataset in combine:
    dataset['Title'] = dataset['Title'].replace(['Lady', 'Countess','Capt', 'Col','Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Other')
    dataset['Title'] = dataset['Title'].replace('Mlle', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')
    
train[['Title', 'Survived']].groupby(['Title'], as_index=False).mean()
# Out:
#     Title  Survived
# 0  Master  0.575000
# 1    Miss  0.702703
# 2      Mr  0.156673
# 3     Mrs  0.793651
# 4   Other  0.347826

# %%
train['fare_band'] = pd.qcut(train['Fare'], 4)
train[['fare_band', 'Survived']].groupby(['fare_band'], as_index=False).mean().sort_values(by='fare_band', ascending=True)
# Out:
#         fare_band  Survived
# 0       [0, 7.91]  0.197309
# 1  (7.91, 14.454]  0.303571
# 2    (14.454, 31]  0.454955
# 3   (31, 512.329]  0.581081

# %%
train['age_band'] = pd.qcut(train['Fare'], 4)
train[['age_band', 'Survived']].groupby(['age_band'], as_index=False).mean().sort_values(by='age_band', ascending=True)
# Out:
#          age_band  Survived
# 0       [0, 7.91]  0.197309
# 1  (7.91, 14.454]  0.303571
# 2    (14.454, 31]  0.454955
# 3   (31, 512.329]  0.581081
